# %%
import pandas as pd
url="/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/sales_predictions_2023.csv"
df=pd.read_csv(url)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.shape
# Out:
# (8523, 12)

# %%
#3) Are there duplicates? If so, drop any duplicates
duplicated_rows=df.duplicated()
duplicated_rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
# there are 0 duplicated
df.duplicated().sum()
# Out:
# 0

# %%
#4) Identify missing values.
df.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
null_sums = df.isna().sum()
null_sums
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
type(null_sums)
# Out:
# pandas.core.series.Series

# %%
# Get the % of null values
null_percent = null_sums/len(df) * 100
null_percent
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
# Dropping Null values from Item_Weight
df = df.dropna(subset=["Item_Weight"])
df['Item_Weight'].isna().sum()
# Out:
# 0

# %%
# Dropping Null values from Outlet_Size
df = df.dropna(subset=["Outlet_Size"])
df['Outlet_Size'].isna().sum()
# Out:
# 0

# %%
null_sums = df.isna().sum()
null_sums
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
from pandas.core.internals.blocks import F
#For any numerical columns, obtain the summary statistics of each (min, max, mean).
from numpy import mean
I_V_mean=df['Item_Outlet_Sales'].mean()
I_V_Max=df['Item_Outlet_Sales'].max()
I_V_min=df['Item_Outlet_Sales'].min
print(f"The Item_Outlet_Sales Max ={I_V_Max}\nThe Item_Outlet_Sales Mean={I_V_mean}\nThe Item_Outlet_Sales Min={I_V_min}")
# Out:
# The Item_Outlet_Sales Max =10256.649
# The Item_Outlet_Sales Mean=2272.0374886021505
# The Item_Outlet_Sales Min=<bound method NDFrame._add_numeric_operations.<locals>.min of 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 4        994.7052
# 5        556.6088
#           ...
# 8517    3608.6360
# 8518    2778.3834
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 4650, dtype: float64>
